# %%
import utils.functional as F
from datasets.generic_dataset import GenericSegmentationDataset
import matplotlib.pyplot as plt

# %%
dataset = GenericSegmentationDataset(root=r'C:\Users\imana\Desktop\lip', mode='train')

# %%
img, _ = dataset.__getitem__(0)
plt.imshow(img)

# %%
mean, std = F.calc_img_mean_std(dataset)
# Out:
# mean: [0.43548067 0.38279098 0.35394864], std: [0.29012242 0.27381756 0.27321091]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30462/30462 [08:00<00:00, 63.39it/s]
